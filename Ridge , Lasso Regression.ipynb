# %% [markdown]
# ### Algerian Forest Fires Dataset
#
# Data set Information:
# The Dataset includes 244 instances that regroup a data of two regions of Algeria, namely the Bejaia region located in the northeast of Algeria and the sidi BEl-abbes region located in the northwest of Algeria .
#
# 122 Instances for each region.
#
# The period from june 2012 to sep 2012. The dataset includes 11 attributes and 1 output attributes(class)The 244 instances have been classified into fires (138 classes) and not fire(106 classes)clasees.

# %% [markdown]
# Attribute Information:
#
# 1.Data: (DD/MM/YYYY) Day,Month(June to September),Year(2012) weather    data observations.
#
# 2.Temp:temperature noon(temperature max) in celsius degree: 22 to 42
#
# 3.RH: Relative humidity in %:21 to 90
#
# 4.WS:Wind speed in km/h :6 to 29
#
# 5.Rain:total day in mm: 0 to 16.8 FWI components
#
# 6.Fine Fuel MOisture code( index from the FWI system : 28.6 to 92.5
#
# 7.Duff Moisture code(DMC): Index from the FWI system :1.1 to 65.9
#
# 8.Drought code(DC):Index from the FWI system: 7 to 220.4
#
# 9.Initial spread index(ISI) Index form the FWI system : 0 to 18.5
#
# 10. Buildup Index(BI):Index from the FWI system : 1.1 to 68
#
# 11.Fire Weather Index(FWI): Index 0 to 31.1
#
# 12.classes : two classes, namely Fire and not Fire

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Algerian_forest_fires_dataset.csv')

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int64
#  1   month        242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4   RH           242 non-null    int64
#  5   Ws           242 non-null    int64
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.5+ KB

# %%
## Data cleaning
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature, RH, Ws, Rain, FFMC, DMC, DC, ISI, BUI, FWI, Classes, Region]
# Index: []

# %% [markdown]
# The data set is converted into two sets based on region form 122 th index. we can make a new column based on the region.
#
# 1: "Beja Region"
#
# 2: "sidi-Bei abbes "
#
#
# ADD new column with Region

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int64
#  1   month        242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4   RH           242 non-null    int64
#  5   Ws           242 non-null    int64
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.5+ KB

# %%
df[['Region']]=df[['Region']].astype(int)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
## Removing null values 
df=df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  \
# 122    2      6  2012           30  73  13   4.0  55.7  2.7  7.8  0.6  2.9
#
#      FWI      Classes  Region
# 122  0.2  not fire          1

# %%
# remove the 122nd row
df=df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  \
# 122    3      6  2012           29  80  14   2.0  48.7  2.2  7.6  0.3  2.6
#
#      FWI      Classes  Region
# 122  0.1  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
## fix spaces in column names
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          241 non-null    int64
#  1   month        241 non-null    int64
#  2   year         241 non-null    int64
#  3   Temperature  241 non-null    int64
#  4   RH           241 non-null    int64
#  5   Ws           241 non-null    int64
#  6   Rain         241 non-null    float64
#  7   FFMC         241 non-null    float64
#  8   DMC          241 non-null    float64
#  9   DC           241 non-null    float64
#  10  ISI          241 non-null    float64
#  11  BUI          241 non-null    float64
#  12  FWI          241 non-null    float64
#  13  Classes      241 non-null    object
#  14  Region       241 non-null    int32
# dtypes: float64(7), int32(1), int64(6), object(1)
# memory usage: 27.4+ KB

# %% [markdown]
# ## change the required columns as integer data type

# %%
df[['month','day', 'year', 'Temperature', 'RH', 'Ws']]=df[['month','day', 'year', 'Temperature', 'RH', 'Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          241 non-null    int32
#  1   month        241 non-null    int32
#  2   year         241 non-null    int32
#  3   Temperature  241 non-null    int32
#  4   RH           241 non-null    int32
#  5   Ws           241 non-null    int32
#  6   Rain         241 non-null    float64
#  7   FFMC         241 non-null    float64
#  8   DMC          241 non-null    float64
#  9   DC           241 non-null    float64
#  10  ISI          241 non-null    float64
#  11  BUI          241 non-null    float64
#  12  FWI          241 non-null    float64
#  13  Classes      241 non-null    object
#  14  Region       241 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 21.8+ KB

# %% [markdown]
# ## changing the other columns to float data type

# %%
objects=[features for features in df.columns if df[features].dtypes=='object']

# %%
for i in objects:
    if i!='Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          241 non-null    int32
#  1   month        241 non-null    int32
#  2   year         241 non-null    int32
#  3   Temperature  241 non-null    int32
#  4   RH           241 non-null    int32
#  5   Ws           241 non-null    int32
#  6   Rain         241 non-null    float64
#  7   FFMC         241 non-null    float64
#  8   DMC          241 non-null    float64
#  9   DC           241 non-null    float64
#  10  ISI          241 non-null    float64
#  11  BUI          241 non-null    float64
#  12  FWI          241 non-null    float64
#  13  Classes      241 non-null    object
#  14  Region       241 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 21.8+ KB

# %%
objects
# Out:
# ['Classes']

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  241.000000  241.000000   241.0   241.000000  241.000000  241.000000
# mean    15.879668    7.514523  2012.0    32.161826   61.958506   15.518672
# std      8.782442    1.110929     0.0     3.640449   14.861525    2.809334
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.000000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   74.000000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  241.000000  241.000000  241.000000  241.000000  241.000000  241.000000
# mean     0.749793   78.020332   14.780913   49.774689    4.776763   16.805394
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
## Let ave the cleaned dataset
df.to_csv('Algerian_forest_fires_dataset.csv',index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %%
df_copy=df.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire          99
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
# Ensure the 'Classes' column is of string type
df_copy['Classes'] = df_copy['Classes'].astype(str)

# %%
## Encoding of the categoreis in classes
df_copy['Classes']=np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 236           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 237           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 238           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 239           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 240           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 236       1
# 237       1
# 238       1
# 239       1
# 240       1

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    104
# Name: count, dtype: int64

# %%
## plot density plot for all feature
plt.style.use('seaborn')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# C:\Users\yashw\AppData\Local\Temp\ipykernel_21764\667533294.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
## Percentage for pie chart
percentage=df_copy['Classes'].value_counts(normalize=True)*100

# %%
import matplotlib.pyplot as plt

# Define the data  # Example percentages, adjust as needed
classlabel = ["Fire", "Not Fire"]

# Create the pie chart
plt.figure(figsize=(12, 7))
plt.pie(percentage, labels=classlabel, autopct='%1.1f%%')
plt.title("Pie Chart of Classes")
plt.show()

# %%
##Correlation
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651791 -0.285644 -0.326499  0.679270  0.486494
# RH             -0.651791  1.000000  0.248148  0.222604 -0.644536 -0.407180
# Ws             -0.285644  0.248148  1.000000  0.171896 -0.175324 -0.005819
# Rain           -0.326499  0.222604  0.171896  1.000000 -0.546470 -0.289482
# FFMC            0.679270 -0.644536 -0.175324 -0.546470  1.000000  0.601527
# DMC             0.486494 -0.407180 -0.005819 -0.289482  0.601527  1.000000
# DC              0.376720 -0.225293  0.075031 -0.298600  0.505185  0.875511
# ISI             0.604948 -0.686103  0.003408 -0.348334  0.738754  0.679150
# BUI             0.460533 -0.352357  0.026542 -0.300574  0.589881  0.982178
# FWI             0.567506 -0.580109  0.027768 -0.325112  0.689822  0.875405
# Classes         0.517203 -0.430794 -0.076262 -0.380263  0.768069  0.583760
# ...

# %%
import seaborn as sns
import pandas as pd

# Example DataFrame
# df = pd.read_csv('your_file.csv') # Uncomment if you are reading from a CSV

# Drop non-numeric columns
df_numeric = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
corr_matrix = df_numeric.corr()

# Plot the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
## BOX plot
sns.boxplot(df['FWI'],color='green')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire', 'fire')

# %%
## Monthly fire analysis
dftemp = df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x="month", hue='Classes',data=df)
plt.ylabel('Number of Fires ',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Sidi- Bel Regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Sidi- Bel Regions')

# %%
## Monthly fire analysis
dftemp = df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x="month", hue='Classes',data=df)
plt.ylabel('Number of Fires ',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Brjaia Regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Brjaia Regions')

# %% [markdown]
#  #Its observed that August ans september has the most number of forest fires for both regions.And from the above plot of months ,we can understand few things

# %% [markdown]
# #Most of the fires happend in August and very high fires happend in only 3 months -june, july and August.

# %% [markdown]
# #Less fires on September
